# %% [markdown]
# ## My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Javier Moya is my name**
#
# and I wanna be a Super Hero

# %% [markdown]
# *I am interested in data science because iste sexiest job in the 21 century*

# %% [markdown]
# ### Now you are going to see my legacy in code ###

# %%
one = 1
two = 2

one + two
# Out:
# 3

# %% [markdown]
# >NOW 2 THINGS ABOUT ME
#
# 1. IM TECHNO DJ
#     2. [AND I HAVE WEBPAGE TOO](https://www.dosisofvitamin-t.club/)
#
# | n| TYPE |
# | ------ | ------ |
# | 1| NUMBERED LIST |
# | A| BULLETED LIST |
# | A| LINK |
# | 2| TABLE|
